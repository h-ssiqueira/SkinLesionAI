# %% [markdown]
# ## Configuration variables
#
# Index | Recommended configuration
# :---: | :---:
# 1 | Rotation up to 20º<br>shear up to 15º<br>Horizontal and vertical flip<br>Vertical and horizontal shift up to 20%<br>Zoom out up to 20%
# 2 | Rotation up to 15º<br>Vertical and horizontal flip<br>Image resize up to 10%

# %%
### Environment
csvMetadataPath = "/content/gdrive/MyDrive/PUC/TCC/Datasets/ham10000/HAM10000_metadata.csv" # "HAM10000_metadata.csv"
imagesPath = "gdrive/MyDrive/PUC/TCC/Datasets/ham10000/imgs/" # "images"
drive = True

### Height and weight of images to be crop
h, w = 224, 224

### Remove duplicates
removeDuplicates = True
removeNv = True
"""
0 0 10015
0 1 3310
1 0 5514
1 1 1099
"""

### Segmentation
segmentation = False
segmentationNum = 100
compactnessNum = 10

### Data augmentation
dataAugmentation = False
rotation = .45
widthShift, heightShift = .1, .1
channelShift = .15
shear = .2
zoom = .25
hFlip, vFlip = True, True
fill = 'nearest' # constant, nearest, reflect, wrap
cval = .5 # case the previous is constant
bright = [.6,1.4]

### Normalization
featureCenter = False
sampleCenter = False
featureStdNorm = False
sampleStdNorm = False
zcaWhitening = False
standardScalerNorm = False
minMaxScalerNorm = False

### Model configuration
epochs = 100
batchSize = 100
if removeNv:
    cancerType = {
        'akiec': 0, # 0.0 - 'Doenca de Bowens'
        'bcc': 1, # 1.0 - 'Carcinoma basocelular'
        'bkl': 2, # 2.0 - 'Keratose benigna'
        'df': 3, # 3.0 - 'Dermatofibroma'
        'vasc': 4, # 4.0 - 'Lesao vascular'
        'mel': 5, # 5.0 - 'Melanoma'
    }
    totalImages = 1099 if removeDuplicates else 3310
else:
    cancerType = {
        'akiec': 0, # 0.0 - 'Doenca de Bowens'
        'bcc': 1, # 1.0 - 'Carcinoma basocelular'
        'bkl': 2, # 2.0 - 'Keratose benigna'
        'df': 3, # 3.0 - 'Dermatofibroma'
        'vasc': 4, # 4.0 - 'Lesao vascular'
        'mel': 5, # 5.0 - 'Melanoma'
        'nv': 6  # 6.0 - 'Nevo melanocitico'
    }
    totalImages = 5514 if removeDuplicates else 10015
totalClasses = len(cancerType)
useCustomOptimizer = False

try:
    tpuFlag = True
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
    print('Not connected to a TPU runtime')
    tpuFlag = False

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Running on TPU  ['10.19.112.66:8470']
# WARNING:tensorflow:TPU system grpc://10.19.112.66:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.

# %% [markdown]
# # Library imports and directory mount

# %%
import matplotlib.pyplot as plt, numpy as np, pandas as pd, seaborn as sns, tensorflow as tf
import cv2, glob, os, random, sys, warnings

from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils

from skimage.segmentation import slic
from skimage.transform import resize

from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_auc_score, f1_score, multilabel_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

warnings.filterwarnings('ignore') 

sns.set() # for ploting

if drive:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # !ls
    # !ls 'gdrive/MyDrive'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# gdrive	sample_data
# 'arq win'				        Invest.gsheet
# 'Ativação windows 10'			        Livros
# 'Colab Notebooks'			       'Mão de obra.gdoc'
#  Currículo				        profile
#  Documentos				        Programação
#  Estudu					        PUC
#  git_auth.txt				        Random
# 'Henrique Sartori Siqueira - Glicemia.gsheet'  'Recuperação de contas'
#  iLovePDF				       'Untitled Diagram.drawio'

# %% [markdown]
# # Dataset import (CSV Metadata)

# %%
datasetMetadata = pd.read_csv(csvMetadataPath)
datasetMetadata = datasetMetadata.drop(columns=['dx_type','age','sex','localization'])
datasetMetadata = datasetMetadata.rename(columns={"lesion_id": "lesionId",
                                                  "image_id": "imageId",
                                                  "dx": "cancerId"})
datasetMetadata.head()
# Out:
#       lesionId       imageId cancerId
# 0  HAM_0000118  ISIC_0027419      bkl
# 1  HAM_0000118  ISIC_0025030      bkl
# 2  HAM_0002730  ISIC_0026769      bkl
# 3  HAM_0002730  ISIC_0025661      bkl
# 4  HAM_0001466  ISIC_0031633      bkl

# %%
datasetMetadata['duplicate'] = datasetMetadata['lesionId']      # Creating a column to indicate if the lesion has more than one image

uniqueLesions = datasetMetadata.groupby('lesionId').count()     # Counts the number of lesions for each id
uniqueLesions = uniqueLesions[uniqueLesions['imageId'] == 1]    # Filter lesions which ones have unique id
uniqueLesions.reset_index(inplace=True)                         # Add default index column
uniqueLesions = uniqueLesions['lesionId'].values.tolist()       # Extracts the indexes into a list

datasetMetadata['duplicate'] = datasetMetadata['duplicate'].apply(lambda x: 0 if x in uniqueLesions else 1) # Fill the rows indicating if the lesion has a duplicated image
datasetMetadata['duplicate'].value_counts()
# Out:
# 0    5514
# 1    4501
# Name: duplicate, dtype: int64

# %% [markdown]
# Removing Duplicates

# %%
if removeDuplicates:
    datasetMetadata = datasetMetadata[datasetMetadata['duplicate'] == 0]
if removeNv:
    datasetMetadata = datasetMetadata[datasetMetadata['cancerId'] != 'nv']
datasetMetadata.head()
# Out:
#        lesionId       imageId cancerId  duplicate
# 10  HAM_0001396  ISIC_0025276      bkl          0
# 15  HAM_0007207  ISIC_0031326      bkl          0
# 20  HAM_0006071  ISIC_0032343      bkl          0
# 33  HAM_0005612  ISIC_0024981      bkl          0
# 34  HAM_0005388  ISIC_0027815      bkl          0

# %%
labelSize = datasetMetadata.groupby('cancerId').size().sort_values() # Sort and order every cancer class

ax = labelSize.plot.barh()
total = datasetMetadata.shape[0]

for i, v in enumerate(labelSize):
    ax.text(v + 3, i + .25, str(v) + ' (' + str(round(v/total*100, 2)) + '%)') # Set the percentage of each cancer class

plt.show()

print(labelSize)
print("Total: ",labelSize.sum())
# Out:
# cancerId
# df        39
# vasc      64
# akiec    151
# bcc      175
# mel      230
# bkl      440
# dtype: int64
# Total:  1099

# %%
datasetMetadata['cancerId'] = datasetMetadata['cancerId'].map(cancerType)
datasetMetadata.head()
# Out:
#        lesionId       imageId  cancerId  duplicate
# 10  HAM_0001396  ISIC_0025276         2          0
# 15  HAM_0007207  ISIC_0031326         2          0
# 20  HAM_0006071  ISIC_0032343         2          0
# 33  HAM_0005612  ISIC_0024981         2          0
# 34  HAM_0005388  ISIC_0027815         2          0

# %% [markdown]
# # Dataset import (Imgs)

# %% [markdown]
# https://scikit-image.org/docs/stable/api/skimage.segmentation.html

# %%
# Path to the dataset images
# /content/gdrive/MyDrive/PUC/TCC/Datasets/ham10000/imgs/<imgId>.jpg

images = []
loadedImages = 0

for index, row in datasetMetadata.iterrows():
    img = cv2.imread(imagesPath+row['imageId']+'.jpg') # Collect the image from drive
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)   # Invert color BGR => RGB
    if segmentation:
        # Segment the image into superpixels using SLIC
        segments = slic(img, n_segments=segmentationNum, compactness=compactnessNum)

        # Resize the superpixels to widthxheight pixels
        resizedSegments = resize(segments, (w, h), order=0, anti_aliasing=False)

        # Reassemble the resized superpixels to form the resized image
        img = resize(img, resizedSegments.shape, order=3, anti_aliasing=True)
    else:
        img = cv2.resize(img, (h, w))            # Resize the image according to params provided
    images.append(img)
    
    loadedImages = loadedImages + 1
    if loadedImages % 1000 == 0:
        print(loadedImages)
# Out:
# 1000

# %%
plt.imshow(images[0])
print(len(images))
print(datasetMetadata.iloc[0])
print(images[0].shape)
plt.show()
# Out:
# 1099
# lesionId      HAM_0001396
# imageId      ISIC_0025276
# cancerId                2
# duplicate               0
# Name: 10, dtype: object
# (224, 224, 3)

# %% [markdown]
# # Images treatment

# %%
images = np.array(images) # Transform images list into np array
print(images[0])
print(images.shape)

images = images.reshape(totalImages, h * w * 3) # 4d -> 2d
print(images.shape)
# Out:
# [[[ 22  11  15]
#   [ 24  12  16]
#   [ 24  12  15]
#   ...
#   [ 61  41  47]
#   [ 63  42  48]
#   [ 63  42  47]]
#
#  [[ 23  12  16]
#   [ 22  11  15]
#   [ 23  12  16]
#   ...
#   [ 61  42  44]
#   [ 63  42  47]
#   [ 60  39  44]]
#
#  [[ 22  10  14]
#   [ 21  12  15]
#   [ 21  12  16]
#   ...
#   [ 60  40  42]
#   [ 61  40  45]
#   [ 62  40  46]]
#
#  ...
#
#  [[ 54  39  46]
#   [ 57  42  47]
#   [ 61  46  50]
#   ...
#   [121 106 104]
#   [115 101 100]
#   [108  96  95]]
#
#  [[ 51  38  45]
#   [ 56  42  48]
#   [ 58  45  52]
#   ...
#   [119 105 104]
#   [114  99  98]
#   [106  90  90]]
#
#  [[ 52  37  44]
#   [ 55  40  47]
#   [ 55  40  50]
#   ...
#   [118 104 103]
#   [107  95  95]
#   [101  87  86]]]
# (1099, 224, 224, 3)
# (1099, 150528)

# %% [markdown]
# ## Model input treatment

# %% [markdown]
# Spliting in training and test balancing the batches by the cancer id

# %%
XTrain, XTest, YTrain, YTest = train_test_split(images,datasetMetadata['cancerId'], test_size = 0.2, train_size = 0.8, stratify=datasetMetadata['cancerId'])

# %% [markdown]
# Normalization

# %%
del images
if minMaxScalerNorm:
    minMaxScaler = MinMaxScaler()
    minMaxScaler.fit(np.asarray(XTrain))

    XTrain = minMaxScaler.transform(XTrain)
    XTest = minMaxScaler.transform(XTest)
elif standardScalerNorm:
    standardScaler = StandardScaler()
    standardScaler.fit(np.asarray(XTrain))

    XTrain = standardScaler.transform(XTrain)
    XTest = standardScaler.transform(XTest)

print(np.shape(XTest))
print(np.shape(XTrain))
print(YTrain.head())
# Out:
# (220, 150528)
# (879, 150528)
# 2049    5
# 2801    1
# 1376    5
# 350     2
# 2431    4
# Name: cancerId, dtype: int64

# %% [markdown]
# Resize

# %%
print(XTrain.shape[0])
print(XTest.shape[0])
XTrain = XTrain.reshape(XTrain.shape[0], h, w, 3).astype('float32')
XTest = XTest.reshape(XTest.shape[0], h, w, 3).astype('float32')

YTrain = np_utils.to_categorical(YTrain)
YTest = np_utils.to_categorical(YTest)

print(XTrain[0].shape)
print(XTrain[0])
# Out:
# 879
# 220
# (224, 224, 3)
# [[[137.  80.  75.]
#   [140.  83.  81.]
#   [140.  85.  81.]
#   ...
#   [148. 103. 110.]
#   [152. 102. 112.]
#   [146.  96. 106.]]
#
#  [[138.  86.  82.]
#   [142.  89.  85.]
#   [141.  88.  82.]
#   ...
#   [146.  95. 105.]
#   [146.  96. 108.]
#   [144.  92. 106.]]
#
#  [[143.  92.  89.]
#   [144.  94.  90.]
#   [141.  92.  87.]
#   ...
#   [145.  90. 106.]
#   [144.  92. 108.]
#   [145.  93. 110.]]
#
#  ...
#
#  [[147.  98.  97.]
#   [148. 104. 104.]
#   [156. 109. 106.]
#   ...
#   [154. 102. 108.]
#   [151.  98. 104.]
#   [152. 100. 106.]]
#
#  [[145.  96.  94.]
#   [151. 102. 106.]
#   [162. 118. 122.]
#   ...
#   [157. 107. 115.]
#   [153. 102. 107.]
#   [150.  98. 103.]]
#
#  [[148.  97.  93.]
#   [149. 101. 101.]
#   [153. 107. 113.]
#   ...
#   [156. 105. 113.]
#   [155. 104. 112.]
#   [151. 102. 109.]]]

# %% [markdown]
# ### Data augmentation
#
# Only be applied in the training set

# %%
if dataAugmentation:
    datagen = ImageDataGenerator(
            # Normalizations
            featurewise_center = featureCenter,
            samplewise_center = sampleCenter,
            featurewise_std_normalization = featureStdNorm,
            samplewise_std_normalization = sampleStdNorm,
            zca_whitening = zcaWhitening,
            # Image modifications
            rotation_range = rotation,
            zoom_range = zoom,
            channel_shift_range = channelShift,
            fill_mode = fill,
            cval = cval,
            width_shift_range = widthShift,
            height_shift_range = heightShift,
            horizontal_flip = hFlip,
            brightness_range = bright,
            shear_range = shear,
            vertical_flip = vFlip)

    print(XTrain.shape)
    print(XTrain.size)
    datagen.fit(XTrain)
    print(XTrain.shape)
    print(XTrain.size)

# %% [markdown]
# # Model training

# %% [markdown]
# Loading pre treined model

# %%
with tpu_strategy.scope(): # creating the model in the TPUStrategy scope means we will train the model on the TPU
    model = tf.keras.applications.ConvNeXtBase(weights='imagenet', include_top=False, classes=totalClasses, input_shape=(h,w,3))

    for layer in model.layers:
        layer.trainable = False

    prediction = tf.keras.layers.Dense(totalClasses, activation='softmax')(tf.keras.layers.Flatten()(model.output))

    model = tf.keras.Model(inputs=model.input, outputs=prediction)

# %%
with tpu_strategy.scope():
    optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
    if useCustomOptimizer:
        model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])
    else:
        model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics=["accuracy"])
    learningRateReduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
with tpu_strategy.scope():
    if dataAugmentation:
        history = model.fit_generator(datagen.flow(XTrain,YTrain, batch_size=batchSize),
                                    epochs = epochs, validation_data = (XTest,YTest),
                                    verbose = 2, steps_per_epoch=XTrain.shape[0] // batchSize,
                                    callbacks=[learningRateReduction])
    else:
        history = model.fit(XTrain, YTrain, validation_data=(XTest, YTest), epochs=epochs, batch_size=batchSize, verbose=2)
# Out:
# Epoch 1/100
# 9/9 - 75s - loss: 10.0157 - accuracy: 0.3322 - val_loss: 5.7635 - val_accuracy: 0.4636 - 75s/epoch - 8s/step
# Epoch 2/100
# 9/9 - 2s - loss: 3.7413 - accuracy: 0.6212 - val_loss: 3.6757 - val_accuracy: 0.5727 - 2s/epoch - 192ms/step
# Epoch 3/100
# 9/9 - 2s - loss: 1.6762 - accuracy: 0.7827 - val_loss: 3.9284 - val_accuracy: 0.6273 - 2s/epoch - 192ms/step
# Epoch 4/100
# 9/9 - 2s - loss: 0.6657 - accuracy: 0.8771 - val_loss: 2.2917 - val_accuracy: 0.6636 - 2s/epoch - 188ms/step
# Epoch 5/100
# 9/9 - 2s - loss: 0.2256 - accuracy: 0.9568 - val_loss: 2.3432 - val_accuracy: 0.6727 - 2s/epoch - 192ms/step
# Epoch 6/100
# 9/9 - 2s - loss: 0.0490 - accuracy: 0.9818 - val_loss: 2.1425 - val_accuracy: 0.6773 - 2s/epoch - 186ms/step
# Epoch 7/100
# 9/9 - 2s - loss: 0.0150 - accuracy: 0.9943 - val_loss: 2.3121 - val_accuracy: 0.6955 - 2s/epoch - 222ms/step
# Epoch 8/100
# 9/9 - 2s - loss: 0.0119 - accuracy: 0.9954 - val_loss: 2.2060 - val_accuracy: 0.7182 - 2s/epoch - 197ms/step
# Epoch 9/100
# 9/9 - 2s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 2.3510 - val_accuracy: 0.6909 - 2s/epoch - 198ms/step
# Epoch 10/100
# 9/9 - 2s - loss: 7.4903e-04 - accuracy: 1.0000 - val_loss: 2.1417 - val_accuracy: 0.7136 - 2s/epoch - 181ms/step
# Epoch 11/100
# 9/9 - 2s - loss: 4.6289e-04 - accuracy: 1.0000 - val_loss: 2.0951 - val_accuracy: 0.7273 - 2s/epoch - 176ms/step
# Epoch 12/100
# 9/9 - 2s - loss: 4.8635e-04 - accuracy: 1.0000 - val_loss: 2.0959 - val_accuracy: 0.7182 - 2s/epoch - 180ms/step
# Epoch 13/100
# 9/9 - 2s - loss: 3.4043e-04 - accuracy: 1.0000 - val_loss: 2.1107 - val_accuracy: 0.7182 - 2s/epoch - 197ms/step
# Epoch 14/100
# 9/9 - 2s - loss: 2.7764e-04 - accuracy: 1.0000 - val_loss: 2.1272 - val_accuracy: 0.7182 - 2s/epoch - 191ms/step
# Epoch 15/100
# 9/9 - 2s - loss: 2.4366e-04 - accuracy: 1.0000 - val_loss: 2.1328 - val_accuracy: 0.7045 - 2s/epoch - 179ms/step
# Epoch 16/100
# 9/9 - 2s - loss: 2.2505e-04 - accuracy: 1.0000 - val_loss: 2.1315 - val_accuracy: 0.7045 - 2s/epoch - 198ms/step
# Epoch 17/100
# 9/9 - 2s - loss: 2.1167e-04 - accuracy: 1.0000 - val_loss: 2.1309 - val_accuracy: 0.7045 - 2s/epoch - 199ms/step
# Epoch 18/100
# 9/9 - 2s - loss: 2.0196e-04 - accuracy: 1.0000 - val_loss: 2.1286 - val_accuracy: 0.7045 - 2s/epoch - 184ms/step
# Epoch 19/100
# 9/9 - 2s - loss: 1.9293e-04 - accuracy: 1.0000 - val_loss: 2.1269 - val_accuracy: 0.7045 - 2s/epoch - 181ms/step
# Epoch 20/100
# 9/9 - 2s - loss: 1.8554e-04 - accuracy: 1.0000 - val_loss: 2.1267 - val_accuracy: 0.7045 - 2s/epoch - 187ms/step
# Epoch 21/100
# 9/9 - 2s - loss: 1.7960e-04 - accuracy: 1.0000 - val_loss: 2.1262 - val_accuracy: 0.7045 - 2s/epoch - 185ms/step
# Epoch 22/100
# 9/9 - 2s - loss: 1.7346e-04 - accuracy: 1.0000 - val_loss: 2.1276 - val_accuracy: 0.7045 - 2s/epoch - 179ms/step
# Epoch 23/100
# 9/9 - 2s - loss: 1.6790e-04 - accuracy: 1.0000 - val_loss: 2.1302 - val_accuracy: 0.7045 - 2s/epoch - 189ms/step
# Epoch 24/100
# 9/9 - 2s - loss: 1.6374e-04 - accuracy: 1.0000 - val_loss: 2.1305 - val_accuracy: 0.7045 - 2s/epoch - 196ms/step
# Epoch 25/100
# 9/9 - 2s - loss: 1.5850e-04 - accuracy: 1.0000 - val_loss: 2.1334 - val_accuracy: 0.7045 - 2s/epoch - 198ms/step
# Epoch 26/100
# 9/9 - 2s - loss: 1.5420e-04 - accuracy: 1.0000 - val_loss: 2.1350 - val_accuracy: 0.7045 - 2s/epoch - 191ms/step
# Epoch 27/100
# 9/9 - 2s - loss: 1.5026e-04 - accuracy: 1.0000 - val_loss: 2.1348 - val_accuracy: 0.7045 - 2s/epoch - 195ms/step
# Epoch 28/100
# 9/9 - 3s - loss: 1.4656e-04 - accuracy: 1.0000 - val_loss: 2.1359 - val_accuracy: 0.7045 - 3s/epoch - 323ms/step
# Epoch 29/100
# 9/9 - 2s - loss: 1.4301e-04 - accuracy: 1.0000 - val_loss: 2.1375 - val_accuracy: 0.7045 - 2s/epoch - 192ms/step
# Epoch 30/100
# 9/9 - 2s - loss: 1.3980e-04 - accuracy: 1.0000 - val_loss: 2.1383 - val_accuracy: 0.7045 - 2s/epoch - 200ms/step
# Epoch 31/100
# 9/9 - 2s - loss: 1.3649e-04 - accuracy: 1.0000 - val_loss: 2.1392 - val_accuracy: 0.7045 - 2s/epoch - 195ms/step
# Epoch 32/100
# 9/9 - 2s - loss: 1.3355e-04 - accuracy: 1.0000 - val_loss: 2.1388 - val_accuracy: 0.7045 - 2s/epoch - 204ms/step
# Epoch 33/100
# 9/9 - 2s - loss: 1.3069e-04 - accuracy: 1.0000 - val_loss: 2.1391 - val_accuracy: 0.7045 - 2s/epoch - 198ms/step
# Epoch 34/100
# 9/9 - 2s - loss: 1.2793e-04 - accuracy: 1.0000 - val_loss: 2.1410 - val_accuracy: 0.7045 - 2s/epoch - 173ms/step
# Epoch 35/100
# 9/9 - 2s - loss: 1.2522e-04 - accuracy: 1.0000 - val_loss: 2.1409 - val_accuracy: 0.7045 - 2s/epoch - 181ms/step
# Epoch 36/100
# 9/9 - 2s - loss: 1.2285e-04 - accuracy: 1.0000 - val_loss: 2.1409 - val_accuracy: 0.7045 - 2s/epoch - 189ms/step
# Epoch 37/100
# 9/9 - 2s - loss: 1.2027e-04 - accuracy: 1.0000 - val_loss: 2.1422 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 38/100
# 9/9 - 2s - loss: 1.1793e-04 - accuracy: 1.0000 - val_loss: 2.1417 - val_accuracy: 0.7045 - 2s/epoch - 185ms/step
# Epoch 39/100
# 9/9 - 2s - loss: 1.1578e-04 - accuracy: 1.0000 - val_loss: 2.1419 - val_accuracy: 0.7045 - 2s/epoch - 177ms/step
# Epoch 40/100
# 9/9 - 2s - loss: 1.1343e-04 - accuracy: 1.0000 - val_loss: 2.1419 - val_accuracy: 0.7045 - 2s/epoch - 197ms/step
# Epoch 41/100
# 9/9 - 2s - loss: 1.1148e-04 - accuracy: 1.0000 - val_loss: 2.1418 - val_accuracy: 0.7045 - 2s/epoch - 196ms/step
# Epoch 42/100
# 9/9 - 2s - loss: 1.0943e-04 - accuracy: 1.0000 - val_loss: 2.1423 - val_accuracy: 0.7045 - 2s/epoch - 181ms/step
# Epoch 43/100
# 9/9 - 2s - loss: 1.0743e-04 - accuracy: 1.0000 - val_loss: 2.1428 - val_accuracy: 0.7045 - 2s/epoch - 177ms/step
# Epoch 44/100
# 9/9 - 2s - loss: 1.0573e-04 - accuracy: 1.0000 - val_loss: 2.1443 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 45/100
# 9/9 - 2s - loss: 1.0392e-04 - accuracy: 1.0000 - val_loss: 2.1452 - val_accuracy: 0.7045 - 2s/epoch - 174ms/step
# Epoch 46/100
# 9/9 - 2s - loss: 1.0224e-04 - accuracy: 1.0000 - val_loss: 2.1438 - val_accuracy: 0.7045 - 2s/epoch - 192ms/step
# Epoch 47/100
# 9/9 - 2s - loss: 1.0046e-04 - accuracy: 1.0000 - val_loss: 2.1439 - val_accuracy: 0.7045 - 2s/epoch - 174ms/step
# Epoch 48/100
# 9/9 - 2s - loss: 9.8979e-05 - accuracy: 1.0000 - val_loss: 2.1437 - val_accuracy: 0.7045 - 2s/epoch - 182ms/step
# Epoch 49/100
# 9/9 - 2s - loss: 9.7349e-05 - accuracy: 1.0000 - val_loss: 2.1440 - val_accuracy: 0.7045 - 2s/epoch - 197ms/step
# Epoch 50/100
# 9/9 - 2s - loss: 9.5736e-05 - accuracy: 1.0000 - val_loss: 2.1457 - val_accuracy: 0.7045 - 2s/epoch - 199ms/step
# Epoch 51/100
# 9/9 - 2s - loss: 9.4354e-05 - accuracy: 1.0000 - val_loss: 2.1457 - val_accuracy: 0.7045 - 2s/epoch - 173ms/step
# Epoch 52/100
# 9/9 - 2s - loss: 9.2826e-05 - accuracy: 1.0000 - val_loss: 2.1459 - val_accuracy: 0.7045 - 2s/epoch - 194ms/step
# Epoch 53/100
# 9/9 - 2s - loss: 9.1542e-05 - accuracy: 1.0000 - val_loss: 2.1460 - val_accuracy: 0.7045 - 2s/epoch - 174ms/step
# Epoch 54/100
# 9/9 - 2s - loss: 9.0241e-05 - accuracy: 1.0000 - val_loss: 2.1463 - val_accuracy: 0.7045 - 2s/epoch - 178ms/step
# Epoch 55/100
# 9/9 - 2s - loss: 8.8907e-05 - accuracy: 1.0000 - val_loss: 2.1460 - val_accuracy: 0.7045 - 2s/epoch - 180ms/step
# Epoch 56/100
# 9/9 - 2s - loss: 8.7712e-05 - accuracy: 1.0000 - val_loss: 2.1468 - val_accuracy: 0.7045 - 2s/epoch - 191ms/step
# Epoch 57/100
# 9/9 - 2s - loss: 8.6410e-05 - accuracy: 1.0000 - val_loss: 2.1459 - val_accuracy: 0.7045 - 2s/epoch - 197ms/step
# Epoch 58/100
# 9/9 - 2s - loss: 8.5226e-05 - accuracy: 1.0000 - val_loss: 2.1461 - val_accuracy: 0.7045 - 2s/epoch - 195ms/step
# Epoch 59/100
# 9/9 - 2s - loss: 8.4068e-05 - accuracy: 1.0000 - val_loss: 2.1447 - val_accuracy: 0.7045 - 2s/epoch - 177ms/step
# Epoch 60/100
# 9/9 - 2s - loss: 8.3010e-05 - accuracy: 1.0000 - val_loss: 2.1453 - val_accuracy: 0.7045 - 2s/epoch - 172ms/step
# Epoch 61/100
# 9/9 - 2s - loss: 8.1801e-05 - accuracy: 1.0000 - val_loss: 2.1469 - val_accuracy: 0.7045 - 2s/epoch - 196ms/step
# Epoch 62/100
# 9/9 - 2s - loss: 8.0658e-05 - accuracy: 1.0000 - val_loss: 2.1472 - val_accuracy: 0.7045 - 2s/epoch - 178ms/step
# Epoch 63/100
# 9/9 - 2s - loss: 7.9658e-05 - accuracy: 1.0000 - val_loss: 2.1462 - val_accuracy: 0.7045 - 2s/epoch - 181ms/step
# Epoch 64/100
# 9/9 - 2s - loss: 7.8603e-05 - accuracy: 1.0000 - val_loss: 2.1469 - val_accuracy: 0.7045 - 2s/epoch - 186ms/step
# Epoch 65/100
# 9/9 - 2s - loss: 7.7589e-05 - accuracy: 1.0000 - val_loss: 2.1470 - val_accuracy: 0.7045 - 2s/epoch - 215ms/step
# Epoch 66/100
# 9/9 - 2s - loss: 7.6581e-05 - accuracy: 1.0000 - val_loss: 2.1472 - val_accuracy: 0.7045 - 2s/epoch - 194ms/step
# Epoch 67/100
# 9/9 - 2s - loss: 7.5596e-05 - accuracy: 1.0000 - val_loss: 2.1464 - val_accuracy: 0.7045 - 2s/epoch - 199ms/step
# Epoch 68/100
# 9/9 - 2s - loss: 7.4671e-05 - accuracy: 1.0000 - val_loss: 2.1468 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 69/100
# 9/9 - 2s - loss: 7.3805e-05 - accuracy: 1.0000 - val_loss: 2.1474 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 70/100
# 9/9 - 2s - loss: 7.2919e-05 - accuracy: 1.0000 - val_loss: 2.1468 - val_accuracy: 0.7045 - 2s/epoch - 177ms/step
# Epoch 71/100
# 9/9 - 2s - loss: 7.2029e-05 - accuracy: 1.0000 - val_loss: 2.1451 - val_accuracy: 0.7045 - 2s/epoch - 173ms/step
# Epoch 72/100
# 9/9 - 2s - loss: 7.1126e-05 - accuracy: 1.0000 - val_loss: 2.1459 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 73/100
# 9/9 - 2s - loss: 7.0295e-05 - accuracy: 1.0000 - val_loss: 2.1464 - val_accuracy: 0.7045 - 2s/epoch - 180ms/step
# Epoch 74/100
# 9/9 - 2s - loss: 6.9517e-05 - accuracy: 1.0000 - val_loss: 2.1472 - val_accuracy: 0.7045 - 2s/epoch - 194ms/step
# Epoch 75/100
# 9/9 - 2s - loss: 6.8709e-05 - accuracy: 1.0000 - val_loss: 2.1472 - val_accuracy: 0.7045 - 2s/epoch - 201ms/step
# Epoch 76/100
# 9/9 - 2s - loss: 6.7849e-05 - accuracy: 1.0000 - val_loss: 2.1474 - val_accuracy: 0.7045 - 2s/epoch - 174ms/step
# Epoch 77/100
# 9/9 - 2s - loss: 6.7169e-05 - accuracy: 1.0000 - val_loss: 2.1473 - val_accuracy: 0.7045 - 2s/epoch - 176ms/step
# Epoch 78/100
# 9/9 - 2s - loss: 6.6386e-05 - accuracy: 1.0000 - val_loss: 2.1460 - val_accuracy: 0.7045 - 2s/epoch - 175ms/step
# Epoch 79/100
# 9/9 - 2s - loss: 6.5668e-05 - accuracy: 1.0000 - val_loss: 2.1464 - val_accuracy: 0.7045 - 2s/epoch - 180ms/step
# Epoch 80/100
# 9/9 - 3s - loss: 6.4926e-05 - accuracy: 1.0000 - val_loss: 2.1463 - val_accuracy: 0.7045 - 3s/epoch - 317ms/step
# Epoch 81/100
# 9/9 - 2s - loss: 6.4206e-05 - accuracy: 1.0000 - val_loss: 2.1464 - val_accuracy: 0.7045 - 2s/epoch - 183ms/step
# Epoch 82/100
# 9/9 - 2s - loss: 6.3545e-05 - accuracy: 1.0000 - val_loss: 2.1459 - val_accuracy: 0.7045 - 2s/epoch - 195ms/step
# Epoch 83/100
# 9/9 - 2s - loss: 6.2861e-05 - accuracy: 1.0000 - val_loss: 2.1466 - val_accuracy: 0.7045 - 2s/epoch - 204ms/step
# Epoch 84/100
# 9/9 - 2s - loss: 6.2282e-05 - accuracy: 1.0000 - val_loss: 2.1479 - val_accuracy: 0.7000 - 2s/epoch - 181ms/step
# Epoch 85/100
# 9/9 - 2s - loss: 6.1572e-05 - accuracy: 1.0000 - val_loss: 2.1461 - val_accuracy: 0.7045 - 2s/epoch - 176ms/step
# Epoch 86/100
# 9/9 - 2s - loss: 6.0905e-05 - accuracy: 1.0000 - val_loss: 2.1470 - val_accuracy: 0.7045 - 2s/epoch - 179ms/step
# Epoch 87/100
# 9/9 - 2s - loss: 6.0290e-05 - accuracy: 1.0000 - val_loss: 2.1459 - val_accuracy: 0.7045 - 2s/epoch - 182ms/step
# Epoch 88/100
# 9/9 - 2s - loss: 5.9692e-05 - accuracy: 1.0000 - val_loss: 2.1472 - val_accuracy: 0.7000 - 2s/epoch - 180ms/step
# Epoch 89/100
# 9/9 - 2s - loss: 5.9068e-05 - accuracy: 1.0000 - val_loss: 2.1466 - val_accuracy: 0.7000 - 2s/epoch - 199ms/step
# Epoch 90/100
# 9/9 - 2s - loss: 5.8488e-05 - accuracy: 1.0000 - val_loss: 2.1455 - val_accuracy: 0.7000 - 2s/epoch - 199ms/step
# Epoch 91/100
# 9/9 - 2s - loss: 5.7864e-05 - accuracy: 1.0000 - val_loss: 2.1455 - val_accuracy: 0.7000 - 2s/epoch - 198ms/step
# Epoch 92/100
# 9/9 - 2s - loss: 5.7297e-05 - accuracy: 1.0000 - val_loss: 2.1457 - val_accuracy: 0.7000 - 2s/epoch - 190ms/step
# Epoch 93/100
# 9/9 - 2s - loss: 5.6779e-05 - accuracy: 1.0000 - val_loss: 2.1458 - val_accuracy: 0.7000 - 2s/epoch - 178ms/step
# Epoch 94/100
# 9/9 - 2s - loss: 5.6141e-05 - accuracy: 1.0000 - val_loss: 2.1455 - val_accuracy: 0.7000 - 2s/epoch - 172ms/step
# Epoch 95/100
# 9/9 - 2s - loss: 5.5620e-05 - accuracy: 1.0000 - val_loss: 2.1450 - val_accuracy: 0.7000 - 2s/epoch - 194ms/step
# Epoch 96/100
# 9/9 - 2s - loss: 5.5066e-05 - accuracy: 1.0000 - val_loss: 2.1453 - val_accuracy: 0.7000 - 2s/epoch - 176ms/step
# Epoch 97/100
# 9/9 - 2s - loss: 5.4556e-05 - accuracy: 1.0000 - val_loss: 2.1449 - val_accuracy: 0.7000 - 2s/epoch - 177ms/step
# Epoch 98/100
# 9/9 - 2s - loss: 5.4035e-05 - accuracy: 1.0000 - val_loss: 2.1451 - val_accuracy: 0.7000 - 2s/epoch - 197ms/step
# Epoch 99/100
# 9/9 - 2s - loss: 5.3547e-05 - accuracy: 1.0000 - val_loss: 2.1454 - val_accuracy: 0.7000 - 2s/epoch - 207ms/step
# Epoch 100/100
# 9/9 - 2s - loss: 5.3049e-05 - accuracy: 1.0000 - val_loss: 2.1465 - val_accuracy: 0.7000 - 2s/epoch - 196ms/step

# %% [markdown]
# # Statistics

# %% [markdown]
# Training epochs statistics

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# General eficiency

# %%
YPredicted = model.predict(XTest)
model.evaluate(XTest,YTest, verbose=0)
# Out:
# 7/7 [==============================] - 13s 1s/step
# [2.144895315170288, 0.699999988079071]

# %% [markdown]
# Confusion matrix

# %%
cm = confusion_matrix(YTest.argmax(axis=1),YPredicted.argmax(axis=1))
class_labels = ['Doenca de Bowens', 'Carcinoma basocelular', 'Keratose benigna', 'Dermatofibroma', 'Lesao vascular', 'Melanoma']
dfCm = pd.DataFrame(cm, index=class_labels, columns=class_labels)

plt.figure(figsize = (12,12))
sns.set(font_scale=1.4) # for label size
sns.heatmap(dfCm, annot=False, annot_kws={"size": 12}) # font size

for i in range(totalClasses):
    for j in range(totalClasses):
        text = plt.text(j + 0.5, i + 0.5, "{:.2f}%".format(cm[i, j] / cm[i].sum() * 100), va="center", ha="center", color="g")

plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 93.24999999999997, 'Predicted label')

# %%
accuracy = accuracy_score(np.argmax(YTest, axis=1), np.argmax(YPredicted, axis=1))
print("Accuracy: ", accuracy)

precision = precision_score(np.argmax(YTest, axis=1), np.argmax(YPredicted, axis=1), average=None)
print("Precision: ", precision)

recall = recall_score(np.argmax(YTest, axis=1), np.argmax(YPredicted, axis=1), average=None)
print("Recall: ", recall)

f1 = f1_score(YTest.argmax(axis=1), YPredicted.argmax(axis=1), average=None)
print("F1-score: ", f1,"\n")

cmMulti = multilabel_confusion_matrix(YTest.argmax(axis=1),YPredicted.argmax(axis=1))
specificity = []
for i in range(len(cmMulti)):
    print('\n',cmMulti[i])
    tn = cmMulti[i][0][0]
    fp = cmMulti[i][0][1]
    specificity.append(tn / (tn + fp))
print("\nSpecificity: ", specificity)

auc = roc_auc_score(YTest, YPredicted, average=None)
print("AUC: ", auc)
# Out:
# Accuracy:  0.7
# Precision:  [0.625      0.59090909 0.72072072 1.         1.         0.67647059]
# Recall:  [0.33333333 0.74285714 0.90909091 0.25       1.         0.5       ]
# F1-score:  [0.43478261 0.65822785 0.8040201  0.4        1.         0.575     ]
#
#
#  [[184   6]
#  [ 20  10]]
#
#  [[167  18]
#  [  9  26]]
#
#  [[101  31]
#  [  8  80]]
#
#  [[212   0]
#  [  6   2]]
#
#  [[207   0]
#  [  0  13]]
#
#  [[163  11]
#  [ 23  23]]
#
# Specificity:  [0.968421052631579, 0.9027027027027027, 0.7651515151515151, 1.0, 1.0, 0.9367816091954023]
# AUC:  [0.8754386  0.91644788 0.9171832  0.94044811 1.         0.8928036 ]

# %% [markdown]
# Saving model into google drive

# %%
#model.save('/content/gdrive/MyDrive/PUC/TCC/Notebooks/simples.h5')
